# %%
# Import the packages we will use
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
loop_mean = np.load('arrs/densities/avg_density_loops_mean_dicty.npy')
loop_sum = np.load('arrs/densities/avg_density_loops_sum_dicty.npy')
interloops_mean = np.load('arrs/densities/avg_density_interloops_mean_dicty.npy')
interloops_sum = np.load('arrs/densities/avg_density_interloops_sum_dicty.npy')

# %%
def plot_loop_and_interloops_density(loop, interloops, isLog=True):
    fig = plt.figure()
    ax = plt.axes()

    if isLog:
        plt.plot(np.log(range(loop.shape[0])), np.log(loop), label='loop');
        plt.plot(np.log(range(interloops.shape[0])), np.log(interloops), label='interloops');
    
    else:
        plt.plot(range(loop.shape[0]), loop, label='loop');
        plt.plot(range(interloops.shape[0]), interloops, label='interloops');
        
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

# %%
plot_loop_and_interloops_density(loop_mean, interloops_mean)
# Out:
# /anaconda3/envs/loops/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /anaconda3/envs/loops/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
plot_loop_and_interloops_density(loop_mean, interloops_mean, isLog=False)

# %%
plot_loop_and_interloops_density(loop_sum, interloops_sum)
# Out:
# /anaconda3/envs/loops/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /anaconda3/envs/loops/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
plot_loop_and_interloops_density(loop_sum, interloops_sum, isLog=False)
