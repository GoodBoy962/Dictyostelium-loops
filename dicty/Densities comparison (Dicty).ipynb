# %%
# Import the packages we will use
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
loop_mean = np.load('arrs/densities/mean_density_loops_mean_dicty.npy')
loop_sum = np.load('arrs/densities/mean_density_loops_sum_dicty.npy')
btw_mean = np.load('arrs/densities/mean_density_btw_mean_dicty.npy')
btw_sum = np.load('arrs/densities/mean_density_btw_sum_dicty.npy')

# %%
def plot_loop_and_btw_density(loop, btw, isLog=True):
    fig = plt.figure()
    ax = plt.axes()

    if isLog:
        plt.plot(np.log(range(loop.shape[0])), np.log(loop), label='loop');
        plt.plot(np.log(range(btw.shape[0])), np.log(btw), label='btw');
    
    else:
        plt.plot(range(loop.shape[0]), loop, label='loop');
        plt.plot(range(btw.shape[0]), btw, label='btw');
        
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

# %%
plot_loop_and_btw_density(loop_mean, btw_mean)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
plot_loop_and_btw_density(loop_mean, btw_mean, isLog=False)

# %%
plot_loop_and_btw_density(loop_sum, btw_sum)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
plot_loop_and_btw_density(loop_sum, btw_sum, isLog=False)
